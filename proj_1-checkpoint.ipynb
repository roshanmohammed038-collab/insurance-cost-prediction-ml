# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')

# %%
num=['age', 'bmi', 'children', 'charges']
for col in num:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col],kde=True,bins=20)

# %%
df_cleaned=df.copy()

# %%
df_cleaned
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_cleaned.shape
# Out:
# (1338, 7)

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (1337, 7)

# %%
df_cleaned.dtypes
# Out:
# age           int64
# sex             str
# bmi         float64
# children      int64
# smoker          str
# region          str
# charges     float64
# dtype: object

# %%
df_cleaned.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_cleaned['sex']=df_cleaned['sex'].map({"male":1,"female":0})

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
df_cleaned.rename(columns={
'sex':'is_female',
    'smoker':' is_smoker'
})
# Out:
#       age  is_female     bmi  children  is_smoker     region      charges
# 0      19          0  27.900         0        yes  southwest  16884.92400
# 1      18          1  33.770         1         no  southeast   1725.55230
# 2      28          1  33.000         3         no  southeast   4449.46200
# 3      33          1  22.705         0         no  northwest  21984.47061
# 4      32          1  28.880         0         no  northwest   3866.85520
# ...   ...        ...     ...       ...        ...        ...          ...
# 1333   50          1  30.970         3         no  northwest  10600.54830
# 1334   18          0  31.920         0         no  northeast   2205.98080
# 1335   18          0  36.850         0         no  southeast   1629.83350
# 1336   21          0  25.800         0         no  southwest   2007.94500
# 1337   61          0  29.070         0        yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print(df_cleaned.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='str')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   str
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   str
#  5   region    1338 non-null   str
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 94.5 KB

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df = pd.get_dummies(df, columns=['region'], drop_first=False)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northeast  \
# 0   19  female  27.900         0    yes  16884.92400             False
# 1   18    male  33.770         1     no   1725.55230             False
# 2   28    male  33.000         3     no   4449.46200             False
# 3   33    male  22.705         0     no  21984.47061             False
# 4   32    male  28.880         0     no   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northeast  \
# 0   19  female  27.900         0    yes  16884.92400             False
# 1   18    male  33.770         1     no   1725.55230             False
# 2   28    male  33.000         3     no   4449.46200             False
# 3   33    male  22.705         0     no  21984.47061             False
# 4   32    male  28.880         0     no   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children smoker      charges  region_northwest  \
# 0   19    0  27.900         0    yes  16884.92400             False
# 1   18    1  33.770         1     no   1725.55230             False
# 2   28    1  33.000         3     no   4449.46200             False
# 3   33    1  22.705         0     no  21984.47061              True
# 4   32    1  28.880         0     no   3866.85520              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
df_cleaned=df.copy()

# %%
df_cleaned.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northeast  \
# 0   19  female  27.900         0    yes  16884.92400             False
# 1   18    male  33.770         1     no   1725.55230             False
# 2   28    male  33.000         3     no   4449.46200             False
# 3   33    male  22.705         0     no  21984.47061             False
# 4   32    male  28.880         0     no   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df_cleaned['sex']=df_cleaned['sex'].map({"male":1,"female":0})

# %%
df_cleaned.rename(columns={
'sex':'is_female',
    'smoker':' is_smoker'
})
# Out:
#       age  is_female     bmi  children  is_smoker      charges  \
# 0      19          0  27.900         0        yes  16884.92400
# 1      18          1  33.770         1         no   1725.55230
# 2      28          1  33.000         3         no   4449.46200
# 3      33          1  22.705         0         no  21984.47061
# 4      32          1  28.880         0         no   3866.85520
# ...   ...        ...     ...       ...        ...          ...
# 1333   50          1  30.970         3         no  10600.54830
# 1334   18          0  31.920         0         no   2205.98080
# 1335   18          0  36.850         0         no   1629.83350
# 1336   21          0  25.800         0         no   2007.94500
# 1337   61          0  29.070         0        yes  29141.36030
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# 0                False             False             False              True
# ...

# %%
df_cleaned['smoker']=df_cleaned['smoker'].map({"yes":1,"no":0})

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northeast  \
# 0   19  female  27.900         0    yes  16884.92400             False
# 1   18    male  33.770         1     no   1725.55230             False
# 2   28    male  33.000         3     no   4449.46200             False
# 3   33    male  22.705         0     no  21984.47061             False
# 4   32    male  28.880         0     no   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    0  27.900         0       1  16884.92400             False
# 1   18    1  33.770         1       0   1725.55230             False
# 2   28    1  33.000         3       0   4449.46200             False
# 3   33    1  22.705         0       0  21984.47061             False
# 4   32    1  28.880         0       0   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df_cleaned=df_cleaned.astype(int)

# %%
df_cleaned.head()
# Out:
#    age  sex  bmi  children  smoker  charges  region_northeast  \
# 0   19    0   27         0       1    16884                 0
# 1   18    1   33         1       0     1725                 0
# 2   28    1   33         3       0     4449                 0
# 3   33    1   22         0       0    21984                 0
# 4   32    1   28         0       0     3866                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %%
df_cleaned['bmi_category']=pd.cut(
    df_cleaned['bmi'],
    bins=[0,18.5,24.9,29.9,float('inf')],
    labels=['underweight','Normal','Over weight','Obese']
)

# %%
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northeast  \
# 0      19    0   27         0       1    16884                 0
# 1      18    1   33         1       0     1725                 0
# 2      28    1   33         3       0     4449                 0
# 3      33    1   22         0       0    21984                 0
# 4      32    1   28         0       0     3866                 0
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    1   30         3       0    10600                 0
# 1334   18    0   31         0       0     2205                 1
# 1335   18    0   36         0       0     1629                 0
# 1336   21    0   25         0       0     2007                 0
# 1337   61    0   29         0       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest bmi_category
# 0                    0                 0                 1  Over weight
# ...

# %%
df_cleaned = pd.get_dummies(df_cleaned, columns=['bmi_category'], drop_first=False)

# %%
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northeast  \
# 0      19    0   27         0       1    16884                 0
# 1      18    1   33         1       0     1725                 0
# 2      28    1   33         3       0     4449                 0
# 3      33    1   22         0       0    21984                 0
# 4      32    1   28         0       0     3866                 0
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    1   30         3       0    10600                 0
# 1334   18    0   31         0       0     2205                 1
# 1335   18    0   36         0       0     1629                 0
# 1336   21    0   25         0       0     2007                 0
# 1337   61    0   29         0       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest  \
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
df_cleaned=df_cleaned.astype(int)

# %%
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northeast  \
# 0      19    0   27         0       1    16884                 0
# 1      18    1   33         1       0     1725                 0
# 2      28    1   33         3       0     4449                 0
# 3      33    1   22         0       0    21984                 0
# 4      32    1   28         0       0     3866                 0
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    1   30         3       0    10600                 0
# 1334   18    0   31         0       0     2205                 1
# 1335   18    0   36         0       0     1629                 0
# 1336   21    0   25         0       0     2007                 0
# 1337   61    0   29         0       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest  \
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
df_cleaned.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest', 'bmi_category_underweight', 'bmi_category_Normal',
#        'bmi_category_Over weight', 'bmi_category_Obese'],
#       dtype='str')

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 6.3 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 7.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 6.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.1 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    - -------------------------------------- 1.0/37.3 MB 5.5 MB/s eta 0:00:07
#    -- ------------------------------------- 2.1/37.3 MB 5.0 MB/s eta 0:00:08
# ...

# %%
from sklearn.preprocessing import StandardScaler
cols=['age','bmi','children']
scaler=StandardScaler()
df_cleaned[cols]=scaler.fit_transform(df_cleaned[cols])

# %%
df_cleaned.to_csv("cleaned_data.csv", index=False)

# %%
df_cleaned = pd.read_csv("cleaned_data.csv")

# %%
df_cleaned.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    0  27.900         0       1  16884.92400             False
# 1   18    1  33.770         1       0   1725.55230             False
# 2   28    1  33.000         3       0   4449.46200             False
# 3   33    1  22.705         0       0  21984.47061             False
# 4   32    1  28.880         0       0   3866.85520             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df_cleaned=df_cleaned.astype(int)

# %%
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northeast  \
# 0      19    0   27         0       1    16884                 0
# 1      18    1   33         1       0     1725                 0
# 2      28    1   33         3       0     4449                 0
# 3      33    1   22         0       0    21984                 0
# 4      32    1   28         0       0     3866                 0
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    1   30         3       0    10600                 0
# 1334   18    0   31         0       0     2205                 1
# 1335   18    0   36         0       0     1629                 0
# 1336   21    0   25         0       0     2007                 0
# 1337   61    0   29         0       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
df_cleaned['bmi_category']=pd.cut(
    df_cleaned['bmi'],
    bins=[0,18.5,24.9,29.9,float('inf')],
    labels=['underweight','Normal','Over weight','Obese']
)

# %%
df_cleaned = pd.get_dummies(df_cleaned, columns=['bmi_category'], drop_first=False)

# %%
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northeast  \
# 0      19    0   27         0       1    16884                 0
# 1      18    1   33         1       0     1725                 0
# 2      28    1   33         3       0     4449                 0
# 3      33    1   22         0       0    21984                 0
# 4      32    1   28         0       0     3866                 0
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    1   30         3       0    10600                 0
# 1334   18    0   31         0       0     2205                 1
# 1335   18    0   36         0       0     1629                 0
# 1336   21    0   25         0       0     2007                 0
# 1337   61    0   29         0       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest  \
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
df_cleaned=df_cleaned.astype(int)

# %%
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northeast  \
# 0      19    0   27         0       1    16884                 0
# 1      18    1   33         1       0     1725                 0
# 2      28    1   33         3       0     4449                 0
# 3      33    1   22         0       0    21984                 0
# 4      32    1   28         0       0     3866                 0
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    1   30         3       0    10600                 0
# 1334   18    0   31         0       0     2205                 1
# 1335   18    0   36         0       0     1629                 0
# 1336   21    0   25         0       0     2007                 0
# 1337   61    0   29         0       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest  \
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
from sklearn.preprocessing import StandardScaler
cols=['bmi','age','children']
scaler=StandardScaler()
df_cleaned[cols]=scaler.fit_transform(df_cleaned[cols])

# %%
df_cleaned
# Out:
#            age  sex       bmi  children  smoker  charges  region_northeast  \
# 0    -1.438764    0 -0.518122 -0.908614       1    16884                 0
# 1    -1.509965    1  0.462657 -0.078767       0     1725                 0
# 2    -0.797954    1  0.462657  1.580926       0     4449                 0
# 3    -0.441948    1 -1.335438 -0.908614       0    21984                 0
# 4    -0.513149    1 -0.354659 -0.908614       0     3866                 0
# ...        ...  ...       ...       ...     ...      ...               ...
# 1333  0.768473    1 -0.027733  1.580926       0    10600                 0
# 1334 -1.509965    0  0.135731 -0.908614       0     2205                 1
# 1335 -1.509965    0  0.953046 -0.908614       0     1629                 0
# 1336 -1.296362    0 -0.845048 -0.908614       0     2007                 0
# 1337  1.551686    0 -0.191196 -0.908614       1    29141                 0
#
#       region_northwest  region_southeast  region_southwest  \
# ...

# %%
from scipy.stats import pearsonr
import pandas as pd

# List of features to check against target
selected_features = [
    'age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'region_northeast', 
    'region_northwest', 'region_southeast', 'region_southwest', 'bmi_category_underweight',
    'bmi_category_Normal', 'bmi_category_Over weight', 'bmi_category_Obese'
]
correlations = {
    feature: pearsonr(df_cleaned[feature], df_cleaned['charges'])[0]
    for feature in selected_features
}

corr = pd.DataFrame(list(correlations.items()), columns=['Feature', 'Pearson Correlation'])

corr = corr.sort_values(by='Pearson Correlation', ascending=False)

print(corr)
# Out:
#                      Feature  Pearson Correlation
# 5                    charges             1.000000
# 4                     smoker             0.787251
# 0                        age             0.299009
# 13        bmi_category_Obese             0.199533
# 2                        bmi             0.196188
# 8           region_southeast             0.073981
# 3                   children             0.067999
# 1                        sex             0.057293
# 6           region_northeast             0.006350
# 7           region_northwest            -0.039905
# 9           region_southwest            -0.043210
# 10  bmi_category_underweight            -0.050484
# 11       bmi_category_Normal            -0.103679
# 12  bmi_category_Over weight            -0.120084

# %% [markdown]
# completed correlation of charges with input

# %%
print(df_cleaned.columns.tolist())
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest', 'bmi_category_underweight', 'bmi_category_Normal', 'bmi_category_Over weight', 'bmi_category_Obese']

# %%
cat=[ 'smoker', 'charges', 'region_northwest', 'region_southeast', 'region_southwest','bmi_category_Normal','bmi_category_Over weight', 'bmi_category_Obese' ]

# %%
from scipy.stats import chi2_contingency
import pandas as pd

alpha = 0.05

# Create bins for target
df_cleaned['charges_bins'] = pd.qcut(df_cleaned['charges'], q=4, labels=False)

chi2_results = {}

for col in cat:
    contingency = pd.crosstab(df_cleaned[col], df_cleaned['charges_bins'])
    
    chi2_stat, p_val, _, _ = chi2_contingency(contingency)
    
    decision = 'Reject Null (Keep Feature)' if p_val < alpha else 'Accept Null (Drop Feature)'
    
    chi2_results[col] = {
        'chi2_statistic': chi2_stat,
        'p_value': p_val,
        'Decision': decision
    }

chi2_df = pd.DataFrame(chi2_results).T

chi2_df = chi2_df.sort_values(by='p_value')

print(chi2_df)
# Out:
#                          chi2_statistic   p_value                    Decision
# smoker                       854.020268       0.0  Reject Null (Keep Feature)
# region_southeast              15.208814  0.001647  Reject Null (Keep Feature)
# charges                          4014.0  0.031305  Reject Null (Keep Feature)
# bmi_category_Obese             8.510101  0.036566  Reject Null (Keep Feature)
# region_southwest               5.530825  0.136807  Accept Null (Drop Feature)
# bmi_category_Over weight       4.620089  0.201826  Accept Null (Drop Feature)
# bmi_category_Normal            3.578987  0.310661  Accept Null (Drop Feature)
# region_northwest               1.226112  0.746749  Accept Null (Drop Feature)

# %%
final_df=df_cleaned[['age','sex','bmi','smoker','charges','region_southwest','bmi_category_Obese']]

# %%
final_df
# Out:
#            age  sex       bmi  smoker  charges  region_southwest  \
# 0    -1.438764    0 -0.518122       1    16884                 1
# 1    -1.509965    1  0.462657       0     1725                 0
# 2    -0.797954    1  0.462657       0     4449                 0
# 3    -0.441948    1 -1.335438       0    21984                 0
# 4    -0.513149    1 -0.354659       0     3866                 0
# ...        ...  ...       ...     ...      ...               ...
# 1333  0.768473    1 -0.027733       0    10600                 0
# 1334 -1.509965    0  0.135731       0     2205                 0
# 1335 -1.509965    0  0.953046       0     1629                 0
# 1336 -1.296362    0 -0.845048       0     2007                 1
# 1337  1.551686    0 -0.191196       1    29141                 0
#
#       bmi_category_Obese
# 0                      0
# 1                      1
# 2                      1
# 3                      0
# 4                      0
# ...                  ...
# ...
